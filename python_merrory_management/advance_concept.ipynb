# %%
print("ankul")

# %%
a="am is going market"

print(a)

# %%
"""
itertor
genretor


decoretor


"""

# %%
# iteroter
# iter
# __iter__
# next()


# genretor 
# yield


# decoretor
# @app


def main(f):

    def __wapper__ (*arg):
        print("befor")
        fun=f()
        print ("after ")
        return  fun
    return __wapper__

@main # main(check)
def check():
    return "ram is good boy"
